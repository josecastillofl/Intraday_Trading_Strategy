# %% [markdown]
# # Intraday Trading Strategy

# %% [markdown]
# ### Intro
#
# This project is a follew step by step work from Youtuber Luke Hardy from [Quant.AI](https://www.quantfactory.ai/), and the main purpuse for me is to expand my knowledge in quant trading.

# %% [markdown]
# ### Importing Libraries

# %%
from statsmodels.regression.rolling import RollingOLS
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np
import datetime as dt
import yfinance as yf
import pandas_ta
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Download S&P500 Data

# %%
# Since there is multiple tables, we only need the first one
sp500 = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# %%
sp500['Symbol'] = sp500['Symbol'].str.replace('.','-')

# %%
stocks_list = sp500['Symbol'].unique().tolist()

# %%
end_date = '2023-11-21'

# %%
start_date = pd.to_datetime(end_date)-pd.DateOffset(365*8)

# %%
data = yf.download(tickers = stocks_list,
                 start = start_date,
                 end = end_date)
# Out:
# [*********************100%%**********************]  503 of 503 completed

# %%
data.head()
# Out:
#             Adj Close                                                   \
#                     A        AAL       AAPL       ABBV ABNB        ABT
# Date
# 2015-11-23  37.476852  40.423809  26.799694  43.283794  NaN  39.117027
# 2015-11-24  38.076035  39.401276  27.056883  43.269634  NaN  39.125652
# 2015-11-25  38.703308  39.477707  26.863419  42.675056  NaN  39.091209
# 2015-11-27  39.293118  39.840862  26.813351  42.469776  NaN  39.099812
# 2015-11-30  39.152691  39.429935  26.924871  41.160305  NaN  38.669399
#
#                                                         ...   Volume           \
#                  ACGL        ACN       ADBE        ADI  ...     WYNN      XEL
# Date                                                    ...
# 2015-11-23  24.643333  94.891479  91.959999  48.095810  ...  2427400  2341500
# 2015-11-24  24.533333  94.460327  92.000000  51.161083  ...  5628300  4416300
# 2015-11-25  24.216667  94.240326  91.769997  51.017124  ...  2358500  2200100
# ...

# %%
df = data.stack()

# %%
df.head()
# Out:
#                  Adj Close      Close       High        Low       Open  \
# Date
# 2015-11-23 A     37.476852  40.029999  40.070000  39.139999  39.290001
#            AAL   40.423809  42.299999  42.740002  41.810001  42.110001
#            AAPL  26.799694  29.437500  29.932501  29.334999  29.817499
#            ABBV  43.283794  61.150002  61.529999  60.840000  61.310001
#            ABT   39.117027  45.439999  46.099998  45.259998  46.029999
#
#                       Volume
# Date
# 2015-11-23 A       6473400.0
#            AAL     4166100.0
#            AAPL  129930000.0
#            ABBV    6405000.0
#            ABT     4593800.0

# %%
df.index.names = ['date', 'ticker']

# %%
df.head()
# Out:
#                    Adj Close      Close       High        Low       Open  \
# date       ticker
# 2015-11-23 A       37.476852  40.029999  40.070000  39.139999  39.290001
#            AAL     40.423809  42.299999  42.740002  41.810001  42.110001
#            AAPL    26.799694  29.437500  29.932501  29.334999  29.817499
#            ABBV    43.283794  61.150002  61.529999  60.840000  61.310001
#            ABT     39.117027  45.439999  46.099998  45.259998  46.029999
#
#                         Volume
# date       ticker
# 2015-11-23 A         6473400.0
#            AAL       4166100.0
#            AAPL    129930000.0
#            ABBV      6405000.0
#            ABT       4593800.0
